# %%
text = "Apple Inc. was founded by Steve Jobs in Cupertino, California.Preecode was founded by Spconnect in Greater Noida , UttarPradesh"

# %%
#!pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import nltk

# %%
#nltk.download("punkt")
#nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
document = ( " Preecode was founded in Greater NOida , Uttar pradesh by two Students . They are currrently learning Ai and machine learning and are planning for ipo for their brain , they are thinking to launch ipo at 500 trillion dollar , they think that the numbers are still less and will increase itThe company is now planning to open a new office in New York City. "
    "Their engineers are running experiments on advanced machine learning models, "
    "and the results have been better than expected. ")

# %%
document
# Out:
# ' Preecode was founded in Greater NOida , Uttar pradesh by two Students . They are currrently learning Ai and machine learning and are planning for ipo for their brain , they are thinking to launch ipo at 500 trillion dollar , they think that the numbers are still less and will increase itThe company is now planning to open a new office in New York City. Their engineers are running experiments on advanced machine learning models, and the results have been better than expected. '

# %%
sentences = sent_tokenize(document)

# %%
print(sentences)
# Out:
# [' Preecode was founded in Greater NOida , Uttar pradesh by two Students .', 'They are currrently learning Ai and machine learning and are planning for ipo for their brain , they are thinking to launch ipo at 500 trillion dollar , they think that the numbers are still less and will increase itThe company is now planning to open a new office in New York City.', 'Their engineers are running experiments on advanced machine learning models, and the results have been better than expected.']

# %%
for i , s in enumerate(sentences):
    print(f"{i}:{s}")
# Out:
# 0: Preecode was founded in Greater NOida , Uttar pradesh by two Students .
# 1:They are currrently learning Ai and machine learning and are planning for ipo for their brain , they are thinking to launch ipo at 500 trillion dollar , they think that the numbers are still less and will increase itThe company is now planning to open a new office in New York City.
# 2:Their engineers are running experiments on advanced machine learning models, and the results have been better than expected.

# %%
from nltk.tokenize import word_tokenize

first_sentence = sentences[0]

print("Using Nltk to summarize" , word_tokenize(first_sentence))
# Out:
# Using Nltk to summarize ['Preecode', 'was', 'founded', 'in', 'Greater', 'NOida', ',', 'Uttar', 'pradesh', 'by', 'two', 'Students', '.']

# %%
all_token = word_tokenize(document)

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

words = ["Running", "runs", "ran", "easily", "fairness", "studies", "better", "geese"]
for w in words:
    print(stemmer.stem(w))
# Out:
# run
# run
# ran
# easili
# fair
# studi
# better
# gees

# %%
from nltk.stem import PorterStemmer

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

for w in words:
    print(f"{w} -- {lemmatizer.lemmatize(w)}")
# Out:
# Running -- Running
# runs -- run
# ran -- ran
# easily -- easily
# fairness -- fairness
# studies -- study
# better -- better
# geese -- goose

# %%
verbs_to_check = ["Running", "runs", "ran", "talking", "studies"]

print("Default (Assumes noun) : \n")
for w in verbs_to_check:
    print(f"{w} --> {lemmatizer.lemmatize(w)}")

print("==="*10)




print("Explicitly told pos(parts of speech) to be verb pos='v' : \n")

for w in verbs_to_check:
    print(f"{w} -- {lemmatizer.lemmatize(w,pos='v')}")
# Out:
# Default (Assumes noun) :
#
# Running --> Running
# runs --> run
# ran --> ran
# talking --> talking
# studies --> study
# ==============================
# Explicitly told pos(parts of speech) to be verb pos='v' :
#
# Running -- Running
# runs -- run
# ran -- run
# talking -- talk
# studies -- study

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

english_stopwords = set(stopwords.words("english"))
print(f"{len(english_stopwords)}")

print(sorted(english_stopwords))
# Out:
# 198
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", "he's", 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', "i'd", "i'll", "i'm", "i've", 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']

# %%
sentence = "My friend talked to Sahiba for 50 mins - The engineers are running experiments on advanced machine learning models "

tokens = word_tokenize(sentence)

# %%
tokens
# Out:
# ['My',
#  'friend',
#  'talked',
#  'to',
#  'Sahiba',
#  'for',
#  '50',
#  'mins',
#  '-',
#  'The',
#  'engineers',
#  'are',
#  'running',
#  'experiments',
#  'on',
#  'advanced',
#  'machine',
#  'learning',
#  'models']

# %%
filtered_tokens = [t for t in tokens if t.lower() not in english_stopwords]

filtered_tokens
# Out:
# ['friend',
#  'talked',
#  'Sahiba',
#  '50',
#  'mins',
#  '-',
#  'engineers',
#  'running',
#  'experiments',
#  'advanced',
#  'machine',
#  'learning',
#  'models']

# %%
def preprocessor(text):
    tokens = word_tokenize(text)
    tokens = [t.lower() for t in tokens]

    tokens = [ t for t in tokens if t not in english_stopwords]

    tokens = [ lemmatizer.lemmatize(t) for t in tokens]
    return tokens

# %%
sample = "The billionaires don't like to spend time on cooking , so they outsource "

print(preprocessor(sample))
# Out:
# ['billionaire', "n't", 'like', 'spend', 'time', 'cooking', ',', 'outsource']

# %% [markdown]
# POS Tagging and NER

# %%
nltk.download("averaged_perception_tagger_eng")
# Out:
# [nltk_data] Error loading averaged_perception_tagger_eng: Package
# [nltk_data]     'averaged_perception_tagger_eng' not found in index
# False

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# %%
sentence = "Apple Inc. was founded by Steve Jobs in Cupertino, California."

tokens = word_tokenize(sentence)

tagged = pos_tag(tokens)

for word , tag in tagged:
    print(f"{word}:{tag}")
# Out:
# Apple:NNP
# Inc.:NNP
# was:VBD
# founded:VBN
# by:IN
# Steve:NNP
# Jobs:NNP
# in:IN
# Cupertino:NNP
# ,:,
# California:NNP
# .:.

# %%
from nltk.corpus import wordnet

def penn_towordnet_pos(penn_tag):
    if penn_tag.startswith("J"):
        return wordnet.ADJ
    elif penn_tag.startswith("V"):
        return wordnet.VERB
        # return 'v'
    elif penn_tag.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN


def preprocess_v2(text):
    tokens = word_tokenize(text)
    tokens = [t.lower() for t in tokens]
    # tokens = [t.lower() for t in token if t.isalpha()] # --> drop the punctuation
    tokens = [t for t in tokens if t not in english_stopwords]
    tagged = pos_tag(tokens)
    # pos=wordnet.VERB --> pos='v'
    return [lemmatizer.lemmatize(word, pos=penn_towordnet_pos(tag)) for word, tag in tagged]

# %%
sample = "The engineers were quickly running several experiments on the advanced learning models."

print("Lemma with POS TAG" , preprocess_v2(sample))
# Out:
# Lemma with POS TAG ['engineer', 'quickly', 'run', 'several', 'experiment', 'advance', 'learning', 'model', '.']

# %%
nltk.download("maxent_ne_chunker_tab")

nltk.download("words")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk import ne_chunk

# %%
sentence = "Apple Inc. was founded by Steve Jobs in Cupertino, California."

tokens = word_tokenize(sentence)

tagged = pos_tag(tokens)

entity_tree = ne_chunk(tagged)

print(entity_tree)
# Out:
# (S
#   (PERSON Apple/NNP)
#   (ORGANIZATION Inc./NNP)
#   was/VBD
#   founded/VBN
#   by/IN
#   (PERSON Steve/NNP Jobs/NNP)
#   in/IN
#   (GPE Cupertino/NNP)
#   ,/,
#   (GPE California/NNP)
#   ./.)

# %% [markdown]
# NER with SPACY

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.8.16)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (0.27.1)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (8.3.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (84.0.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: colorama in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click<9.0.0,>=8.2.1->spacy) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\sahil\AppData\Roaming\Python\Python313\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->spacy) (3.0.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
# Out:
# c:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.2) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.8 MB 1.3 MB/s eta 0:00:10
#      --- ------------------------------------ 1.0/12.8 MB 1.3 MB/s eta 0:00:10
#      ---- ----------------------------------- 1.6/12.8 MB 1.3 MB/s eta 0:00:09
#      ----- ---------------------------------- 1.8/12.8 MB 1.4 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.4 MB/s eta 0:00:08
#      -------- ------------------------------- 2.6/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.4/12.8 MB 1.5 MB/s eta 0:00:07
#      ------------ --------------------------- 3.9/12.8 MB 1.3 MB/s eta 0:00:08
#      ------------- -------------------------- 4.2/12.8 MB 1.3 MB/s eta 0:00:07
#      -------------- ------------------------- 4.7/12.8 MB 1.4 MB/s eta 0:00:06
#      ----------------- ---------------------- 5.5/12.8 MB 1.5 MB/s eta 0:00:05
#      ------------------ --------------------- 6.0/12.8 MB 1.5 MB/s eta 0:00:05
#      -------------------- ------------------- 6.6/12.8 MB 1.6 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.3/12.8 MB 1.7 MB/s eta 0:00:04
#      ------------------------ --------------- 7.9/12.8 MB 1.7 MB/s eta 0:00:03
#      -------------------------- ------------- 8.4/12.8 MB 1.8 MB/s eta 0:00:03
#      --------------------------- ------------ 8.9/12.8 MB 1.8 MB/s eta 0:00:03
#      ---------------------------- ----------- 9.2/12.8 MB 1.8 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.4/12.8 MB 1.8 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 1.8 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 1.8 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.8 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.8 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.8 MB/s  0:00:07
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# c:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.2) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nlp = spacy.load("en_core_web_sm")

# %%
sentence = "Apple Inc. was founded by Steve Jobs in Cupertino, California."

# %%
doc = nlp(sentence)
