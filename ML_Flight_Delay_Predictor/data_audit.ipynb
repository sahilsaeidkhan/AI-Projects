# %%
import pandas as pd
import numpy as np
import pathlib as Path

# %%
from pathlib import Path

DATA_PATH = Path("./data")

list(DATA_PATH.iterdir())
# Out:
# [WindowsPath('data/T_ONTIME_REPORTING.csv')]

# %%
df = pd.read_csv(DATA_PATH / "T_ONTIME_REPORTING.csv")

# %%
df.shape
# Out:
# (539747, 20)

# %%
df.head(10)
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2025      1             1            3  1/1/2025 12:00:00 AM
# 1  2025      1             1            3  1/1/2025 12:00:00 AM
# 2  2025      1             1            3  1/1/2025 12:00:00 AM
# 3  2025      1             1            3  1/1/2025 12:00:00 AM
# 4  2025      1             1            3  1/1/2025 12:00:00 AM
# 5  2025      1             1            3  1/1/2025 12:00:00 AM
# 6  2025      1             1            3  1/1/2025 12:00:00 AM
# 7  2025      1             1            3  1/1/2025 12:00:00 AM
# 8  2025      1             1            3  1/1/2025 12:00:00 AM
# 9  2025      1             1            3  1/1/2025 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM       ORIGIN_CITY_NAME  \
# 0                AA                  1           New York, NY
# 1                AA                 10        Los Angeles, CA
# 2                AA               1002            Madison, WI
# 3                AA               1004       Philadelphia, PA
# 4                AA               1005            Chicago, IL
# 5                AA               1006   Colorado Springs, CO
# 6                AA               1006  Dallas/Fort Worth, TX
# 7                AA               1007          Charlotte, NC
# 8                AA               1008           New York, NY
# 9                AA               1009              Eagle, CO
#
#   ORIGIN_STATE_ABR         DEST_CITY_NAME DEST_STATE_ABR  CRS_DEP_TIME  \
# 0               NY        Los Angeles, CA             CA           659
# 1               CA           New York, NY             NY          2200
# 2               WI          Charlotte, NC             NC           644
# 3               PA          Las Vegas, NV             NV          1855
# 4               IL            Phoenix, AZ             AZ           830
# 5               CO  Dallas/Fort Worth, TX             TX          1634
# 6               TX   Colorado Springs, CO             CO          1500
# 7               NC          St. Louis, MO             MO          2042
# 8               NY          Charlotte, NC             NC          1915
# 9               CO              Miami, FL             FL          1100
#
#   DEP_TIME_BLK  CRS_ARR_TIME  ARR_DELAY  ARR_DEL15  CANCELLED  DIVERTED  \
# 0    0600-0659          1020       -7.0        0.0        0.0       0.0
# 1    2200-2259           630      -47.0        0.0        0.0       0.0
# 2    0600-0659          1005       20.0        1.0        0.0       0.0
# 3    1800-1859          2134       -7.0        0.0        0.0       0.0
# 4    0800-0859          1131       44.0        1.0        0.0       0.0
# 5    1600-1659          1927       -5.0        0.0        0.0       0.0
# 6    1500-1559          1554       -2.0        0.0        0.0       0.0
# 7    2000-2059          2153       -6.0        0.0        0.0       0.0
# 8    1900-1959          2125       -8.0        0.0        0.0       0.0
# 9    1100-1159          1713       36.0        1.0        0.0       0.0
#
#    CRS_ELAPSED_TIME  DISTANCE
# 0             381.0    2475.0
# 1             330.0    2475.0
# 2             141.0     708.0
# 3             339.0    2176.0
# 4             241.0    1440.0
# 5             113.0     592.0
# 6             114.0     592.0
# 7             131.0     575.0
# 8             130.0     544.0
# 9             253.0    1810.0
