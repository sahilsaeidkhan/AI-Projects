# %%
import pandas as pd , numpy as np 
from pathlib import Path
import os

# %%
data_path = Path("./data/loan_approval_dataset.csv")
print("Dataset exits : ",data_path.exists())
# Out:
# Dataset exits :  True

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df = df.drop(columns=['loan_id'])
df.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
df.columns
# Out:
# Index([' no_of_dependents', ' education', ' self_employed', ' income_annum',
#        ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# [' no_of_dependents', ' education', ' self_employed', ' income_annum', ' loan_amount', ' loan_term', ' cibil_score', ' residential_assets_value', ' commercial_assets_value', ' luxury_assets_value', ' bank_asset_value', ' loan_status']

# %%
print('loan_id'in df.columns)
# Out:
# False

# %%
for col in df.columns:
    print(repr(col))
# Out:
# ' no_of_dependents'
# ' education'
# ' self_employed'
# ' income_annum'
# ' loan_amount'
# ' loan_term'
# ' cibil_score'
# ' residential_assets_value'
# ' commercial_assets_value'
# ' luxury_assets_value'
# ' bank_asset_value'
# ' loan_status'

# %%
df.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       no_of_dependents      education self_employed  income_annum  \
# 0                    2       Graduate            No       9600000
# 1                    0   Not Graduate           Yes       4100000
# 2                    3       Graduate            No       9100000
# 3                    3       Graduate            No       8200000
# 4                    5   Not Graduate           Yes       9800000
# ...                ...            ...           ...           ...
# 4264                 5       Graduate           Yes       1000000
# 4265                 0   Not Graduate           Yes       3300000
# 4266                 2   Not Graduate            No       6500000
# 4267                 1   Not Graduate            No       4100000
# 4268                 1       Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0        29900000         12          778                   2400000
# ...

# %%
df.shape
# Out:
# (4269, 12)

# %%
df.columns.tolist()
# Out:
# [' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
df.columns = df.columns.str.strip()
df.columns.tolist()
# Out:
# ['no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
df.isnull().sum()
# Out:
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.describe()
# Out:
#        no_of_dependents  income_annum   loan_amount    loan_term  cibil_score  \
# count       4269.000000  4.269000e+03  4.269000e+03  4269.000000  4269.000000
# mean           2.498712  5.059124e+06  1.513345e+07    10.900445   599.936051
# std            1.695910  2.806840e+06  9.043363e+06     5.709187   172.430401
# min            0.000000  2.000000e+05  3.000000e+05     2.000000   300.000000
# 25%            1.000000  2.700000e+06  7.700000e+06     6.000000   453.000000
# 50%            3.000000  5.100000e+06  1.450000e+07    10.000000   600.000000
# 75%            4.000000  7.500000e+06  2.150000e+07    16.000000   748.000000
# max            5.000000  9.900000e+06  3.950000e+07    20.000000   900.000000
#
#        residential_assets_value  commercial_assets_value  luxury_assets_value  \
# count              4.269000e+03             4.269000e+03         4.269000e+03
# mean               7.472617e+06             4.973155e+06         1.512631e+07
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
df.columns.tolist()
# Out:
# ['no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
target_col = 'loan_status'

# %%
print('Using target column:', target_col)
display(df[target_col].value_counts(dropna=False))
sns.countplot(x=target_col, data=df)
plt.title('Target distribution')
plt.show()
# Out:
# Using target column: loan_status
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %% [markdown]
# cibil score and loan term is influencing in approving or rejecting a loan

# %%
numeric_cols = df.select_dtypes(include='number').columns

df.groupby('loan_status')[numeric_cols].mean().T
# Out:
# loan_status                   Approved      Rejected
# no_of_dependents          2.474774e+00  2.538128e+00
# income_annum              5.025904e+06  5.113825e+06
# loan_amount               1.524725e+07  1.494606e+07
# loan_term                 1.039759e+01  1.172846e+01
# cibil_score               7.034620e+02  4.294681e+02
# residential_assets_value  7.399812e+06  7.592498e+06
# commercial_assets_value   5.001355e+06  4.926720e+06
# luxury_assets_value       1.501660e+07  1.530694e+07
# bank_asset_value          4.959526e+06  5.004960e+06

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='loan_status', y='cibil_score')
plt.title('CIBIL Score by Loan Status')
plt.show()

# %% [markdown]
# checking for all features

# %%
features = [
    'income_annum',
    'loan_amount',
    'loan_term',
    'cibil_score',
    'residential_assets_value',
    'commercial_assets_value',
    'luxury_assets_value',
    'bank_asset_value'
]

for col in features:
    sns.boxplot(data=df, x='loan_status', y=col)
    plt.title(f'{col} by Loan Status')
    plt.show()

# %% [markdown]
# Splitting the data

# %%
X = df.drop(columns = ['loan_status'])
y = df['loan_status']

# %%
print(X.columns)
print(y.name)
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value'],
#       dtype='object')
# loan_status

# %% [markdown]
# Seperating Columns ( category and numerical)

# %%
cat_cols = X.select_dtypes(include=['object','category']).columns.tolist()
num_cols = X.select_dtypes(include=[np.number]).columns.tolist()

# %%
print(cat_cols)
print(numeric_cols)
# Out:
# ['education', 'self_employed']
# Index(['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term',
#        'cibil_score', 'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value'],
#       dtype='object')

# %% [markdown]
# Filling missing values , Scaling the data and Creating Pipeline , transformer

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder ,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# Creating Pipeline that they can run sequentially

# %%
numeric_transformer = Pipeline(steps=[("imputer" , SimpleImputer   (strategy = 'median')),
           ('scaler' , StandardScaler() )                           ])

# %%
categorical_transformer = Pipeline(steps = [  ('imputer' , SimpleImputer ( strategy='most_frequent')),
        ("onehot",OneHotEncoder (handle_unknown="ignore"))])

# %% [markdown]
# Creating Transofrmer that both Pipeline can run Parallelly

# %%
preprocessor = ColumnTransformer(transformers = [('num', numeric_transformer, num_cols),("cat" , categorical_transformer,cat_cols)] , remainder='drop')

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['no_of_dependents', 'income_annum',
#                                   'loan_amount', 'loan_term', 'cibil_score',
#                                   'residential_assets_value',
#                                   'commercial_assets_value',
#                                   'luxury_assets_value', 'bank_asset_value']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %% [markdown]
# Stage -1 : Classification baseline , we will test with different models , and the one which will be best , we will use in final way

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
# pip install xgboost

# %%
unique_vals = sorted(y.unique())

unique_vals
# Out:
# [' Approved', ' Rejected']

# %%
y = (y == ' Approved').astype(int)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int64

# %%
X_train , X_test , y_train , y_test = train_test_split ( X , y , test_size=0.2 , random_state= 56 , stratify = y )

print("Train/test sizes:" , X_train.shape , X_test.shape , y_train.shape ,y_test.shape )
# Out:
# Train/test sizes: (3415, 11) (854, 11) (3415,) (854,)

# %% [markdown]
# Fit RF baseline pipelines

# %%
rf_pipeline = Pipeline(steps = [ ( 'preprocessor' , preprocessor) ,
                                 ('rf' , RandomForestClassifier(random_state = 2 , oob_score = True )  )])

# %%
# !pip install scikit-learn

# %%
param_grid = { 'rf__n_estimators': [100,200,300,400],
              'rf__max_depth':[None,4,8,10],
              'rf__max_features': ['sqrt',None]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV( rf_pipeline , param_grid ,  cv = 5 , scoring = 'f1' , n_jobs = -1)
grid.fit ( X_train , y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['no_of_dependents',
#                                                                           'income_annum',
#                                                                           'loan_amount',
#                                                                           'loan_term',
# ...

# %%
print("Best params ( RF) :" , grid.best_params_)
# Out:
# Best params ( RF) : {'rf__max_depth': None, 'rf__max_features': None, 'rf__n_estimators': 400}

# %%
best_clf = grid.best_estimator_
print(best_clf)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['no_of_dependents',
#                                                    'income_annum',
#                                                    'loan_amount', 'loan_term',
#                                                    'cibil_score',
#                                                    'residential_assets_value',
#                                                    'commercial_assets_value',
#                                                    'luxury_assets_value',
# ...

# %%
y_pred_best = best_clf.predict(X_test)

print(classification_report(y_test , y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       323
#            1       0.98      0.99      0.99       531
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %%
rf_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('rf', RandomForestClassifier(n_estimators=400, max_depth=10,
                                                            max_features=None,random_state=2, 
                                                            oob_score=True))])

# %%
rf_pipeline.fit(X_train, y_train)
y_pred_rf = rf_pipeline.predict(X_test)
print('Random Forest:')
print(classification_report(y_test, y_pred_rf))
print('RF OOB score (if available):', getattr(rf_pipeline.named_steps['rf'],'oob_score_', None))
# Out:
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       323
#            1       0.98      1.00      0.99       531
#
#     accuracy                           0.98       854
#    macro avg       0.99      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
# RF OOB score (if available): 0.9856515373352855

# %%
getattr(rf_pipeline.named_steps['rf'],'feature_importances_',None)
# Out:
# array([2.55845998e-03, 2.17555155e-02, 2.97344237e-02, 8.09057642e-02,
#        8.40351437e-01, 5.00819702e-03, 5.73251360e-03, 9.20597178e-03,
#        3.61852542e-03, 2.32114647e-04, 2.06831451e-04, 4.16516532e-04,
#        2.73729079e-04])

# %%
# Get the trained Random Forest
rf_model = rf_pipeline.named_steps['rf']

# Get feature names after preprocessing
feature_names = rf_pipeline.named_steps['preprocessor'].get_feature_names_out()

# Get feature importance
importances = rf_model.feature_importances_

# Combine names + importance
feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

# Sort from most important to least important
feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importance)
# Out:
#                           Feature  Importance
# 4                num__cibil_score    0.840351
# 3                  num__loan_term    0.080906
# 2                num__loan_amount    0.029734
# 1               num__income_annum    0.021756
# 7        num__luxury_assets_value    0.009206
# 6    num__commercial_assets_value    0.005733
# 5   num__residential_assets_value    0.005008
# 8           num__bank_asset_value    0.003619
# 0           num__no_of_dependents    0.002558
# 11         cat__self_employed_ No    0.000417
# 12        cat__self_employed_ Yes    0.000274
# 9        cat__education_ Graduate    0.000232
# 10   cat__education_ Not Graduate    0.000207

# %% [markdown]
# Now Creating a model to predict how much loan to offer to the approved applicant

# %%
df['loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df['loan_status'] = df['loan_status'].astype(str).str.strip().str.lower()

# %%
# filter data for approved loans only
approved_df = df [ df['loan_status'] == "approved"].copy()

# %%
approved_df.head()
# Out:
#     no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                  2   Graduate            No       9600000     29900000
# 6                  5   Graduate            No       8700000     33000000
# 8                  0   Graduate           Yes        800000      2200000
# 10                 4   Graduate           Yes       2900000     11200000
# 13                 2   Graduate           Yes       9100000     31500000
#
#     loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0          12          778                   2400000                 17600000
# 6           4          678                  22500000                 14800000
# 8          20          782                   1300000                   800000
# 10          2          547                   8100000                  4700000
# 13         14          679                  10800000                 16600000
#
#     luxury_assets_value  bank_asset_value loan_status
# ...

# %%
reg_target = "loan_amount"
reg_df = approved_df.dropna(subset=[reg_target]).copy()

# %%
X_reg = reg_df.drop(columns = [ reg_target])
y_reg = reg_df[reg_target]

# %%
num_cols_reg = X_reg.select_dtypes(include=['int64','float64']).columns.tolist()
cat_cols_reg = X_reg.select_dtypes(include=['object']).columns.tolist()

# %%
print("Regression Numerical:", num_cols_reg)
print("Regression Categorical:", cat_cols_reg)
# Out:
# Regression Numerical: ['no_of_dependents', 'income_annum', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']
# Regression Categorical: ['education', 'self_employed', 'loan_status']

# %%
Xr_train , Xr_test , yr_train , yr_test = train_test_split(X_reg , y_reg , random_state= 42 , test_size= 0.2)

# %% [markdown]
# processor for automatically processing the data

# %%
reg_preprocessor = ColumnTransformer( transformers=[
    ("num" , StandardScaler(), num_cols_reg),("cat" , OneHotEncoder ( handle_unknown='ignore') , cat_cols_reg)
], remainder = 'drop')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg_pipe = Pipeline(steps = [ ( 'preprocessor' , reg_preprocessor) , ('model', RandomForestRegressor( random_state = 42 , oob_score = True))])

# %%
param_grid_reg = {
    "model__n_estimators": [100, 200, 300],
    "model__max_depth": [None, 5, 10],
    "model__min_samples_split": [2, 5, 10]
}

# %%
grid_reg = GridSearchCV(
    reg_pipe,
    param_grid_reg,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

# %%
Xr_train.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
grid_reg.fit(Xr_train , yr_train 
)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['no_of_dependents',
#                                                                           'income_annum',
#                                                                           'loan_term',
#                                                                           'cibil_score',
#                                                                           'residential_assets_value',
#                                                                           'commercial_assets_value',
#                                                                           'luxury_assets_value',
# ...

# %%
print("Best Regression Params:" , grid_reg.best_params_)
best_reg = grid_reg.best_estimator_
print(best_reg)
# Out:
# Best Regression Params: {'model__max_depth': 5, 'model__min_samples_split': 10, 'model__n_estimators': 300}
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['no_of_dependents',
#                                                    'income_annum', 'loan_term',
#                                                    'cibil_score',
#                                                    'residential_assets_value',
#                                                    'commercial_assets_value',
#                                                    'luxury_assets_value',
#                                                    'bank_asset_value']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['education', 'self_employed',
# ...

# %%
grid_reg.best_score_
# Out:
# np.float64(0.8678578718038459)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error ,r2_score

# %%
reg_pipe = Pipeline(steps=[('preprocessor', reg_preprocessor), ('model' , RandomForestRegressor( max_depth=5 , min_samples_split=10 , n_estimators=300 , random_state=42,oob_score=True))])

# %%
reg_pipe.fit(Xr_train , yr_train)
yr_pred = reg_pipe.predict(Xr_test)

# %%
print("Regression metrics on approved applicants:")
print("MSE:" , mean_squared_error(yr_test , yr_pred))
# Out:
# Regression metrics on approved applicants:
# MSE: 10794004746004.68

# %%
print("MAE:" , mean_absolute_error(yr_test, yr_pred))

print("R2:" , r2_score(yr_test, yr_pred))
# Out:
# MAE: 2451526.9067810844
# R2: 0.8744177380038414

# %%
comparison = pd.DataFrame({
    "Actual Loan Amount": yr_test.values,
    "Predicted Loan Amount": yr_pred
})

comparison["Predicted Loan Amount"] = comparison["Predicted Loan Amount"].round(0).astype(int)

print(comparison)
# Out:
#      Actual Loan Amount  Predicted Loan Amount
# 0              15500000               11905403
# 1              16400000               19607637
# 2               8600000                6862033
# 3              10700000               15380366
# 4              17300000               19367949
# ..                  ...                    ...
# 527             2800000                3373720
# 528            11000000                8057807
# 529            11500000               14353985
# 530            10600000                9724973
# 531             5300000                4814489
#
# [532 rows x 2 columns]

# %% [markdown]
# Saving artificats and combined predict function

# %%
import joblib

# %%
joblib.dump(rf_pipeline , './models/stage_1_rf_classifier_pipeline.pkl')

joblib.dump(reg_pipe , './models/stage_2_rf_regression_pipeline.pkl' )
# Out:
# ['./models/stage_2_rf_regression_pipeline.pkl']

# %% [markdown]
# Prediction Function

# %%
clf = joblib.load('./models/stage_1_rf_classifier_pipeline.pkl')

reg = joblib.load('./models/stage_2_rf_regression_pipeline.pkl')

# %%
user_input = {
    "no_of_dependents": int(input("No. of Dependents: ")),
        "education": input("Education (Graduate/Not Graduate): "),
        "self_employed": input("Self Employed (Yes/No): "),
        "income_annum": float(input("Annual Income: ")),
        "loan_amount": float(input("Loan Amount Requested: ")),
        "loan_term": int(input("Loan Term (in years): ")),
        "cibil_score": int(input("CIBIL Score: ")),
        "residential_assets_value": float(input("Residential Assets Value: ")),
        "commercial_assets_value": float(input("Commercial Assets Value: ")),
        "luxury_assets_value": float(input("Luxury Assets Value: ")),
        "bank_asset_value": float(input("Bank Asset Value: "))
}

applicant_df = pd.DataFrame([user_input])

# %%
def two_stage_predict(applicant_df):
    out = {}

    # stage 1 - loan will be approved or not 

    approve = clf.predict(applicant_df)[0]  
    print(approve)
    out['loan_status'] = int(approve)


    if approve == 1 :
        applicant_df_reg = applicant_df.copy()
        applicant_df_reg['loan_status'] = "approved"

        #prediction 
        pred = reg.fit(applicant_df_reg)[0]
        out['regression_prediction'] = float(pred)

    else:
        print("Not approved")

    return out

# %%
result = two_stage_predict(applicant_df)

print("Final output")
print(result)
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 result = two_stage_predict(applicant_df)
#       3 print("Final output")
#       4 print(result)
#
# Cell In[235], line 16, in two_stage_predict(applicant_df)
#      13     applicant_df_reg['loan_status'] = "approved"
#      15     #prediction
# ---> 16     pred = reg.fit(applicant_df_reg)[0]
#      17     out['regression_prediction'] = float(pred)
#      19 else:
#
# File c:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# ...
