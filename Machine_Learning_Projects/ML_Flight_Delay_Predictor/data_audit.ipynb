# %%
import pandas as pd
import numpy as np
import pathlib as Path

# %%
from pathlib import Path

DATA_PATH = Path("./data")

list(DATA_PATH.iterdir())
# Out:
# [WindowsPath('data/T_ONTIME_REPORTING.csv')]

# %%
df = pd.read_csv(DATA_PATH / "T_ONTIME_REPORTING.csv")

# %%
df.shape
# Out:
# (539747, 20)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2025      1             1            3  1/1/2025 12:00:00 AM
# 1  2025      1             1            3  1/1/2025 12:00:00 AM
# 2  2025      1             1            3  1/1/2025 12:00:00 AM
# 3  2025      1             1            3  1/1/2025 12:00:00 AM
# 4  2025      1             1            3  1/1/2025 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# 0                AA                  1      New York, NY               NY
# 1                AA                 10   Los Angeles, CA               CA
# 2                AA               1002       Madison, WI               WI
# 3                AA               1004  Philadelphia, PA               PA
# 4                AA               1005       Chicago, IL               IL
#
#     DEST_CITY_NAME DEST_STATE_ABR  CRS_DEP_TIME DEP_TIME_BLK  CRS_ARR_TIME  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539747 entries, 0 to 539746
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   YEAR               539747 non-null  int64
#  1   MONTH              539747 non-null  int64
#  2   DAY_OF_MONTH       539747 non-null  int64
#  3   DAY_OF_WEEK        539747 non-null  int64
#  4   FL_DATE            539747 non-null  object
#  5   OP_UNIQUE_CARRIER  539747 non-null  object
#  6   OP_CARRIER_FL_NUM  539747 non-null  int64
#  7   ORIGIN_CITY_NAME   539747 non-null  object
#  8   ORIGIN_STATE_ABR   539747 non-null  object
#  9   DEST_CITY_NAME     539747 non-null  object
#  10  DEST_STATE_ABR     539747 non-null  object
#  11  CRS_DEP_TIME       539747 non-null  int64
#  12  DEP_TIME_BLK       539747 non-null  object
#  13  CRS_ARR_TIME       539747 non-null  int64
#  14  ARR_DELAY          522269 non-null  float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# ARR_DEL15            17478
# ARR_DELAY            17478
# YEAR                     0
# MONTH                    0
# DAY_OF_WEEK              0
# DAY_OF_MONTH             0
# FL_DATE                  0
# OP_UNIQUE_CARRIER        0
# ORIGIN_STATE_ABR         0
# DEST_CITY_NAME           0
# OP_CARRIER_FL_NUM        0
# ORIGIN_CITY_NAME         0
# CRS_DEP_TIME             0
# DEST_STATE_ABR           0
# CRS_ARR_TIME             0
# DEP_TIME_BLK             0
# CANCELLED                0
# DIVERTED                 0
# CRS_ELAPSED_TIME         0
# DISTANCE                 0
# dtype: int64

# %%
df[df["ARR_DEL15"].isnull()][["CANCELLED", "DIVERTED"]].value_counts()
# Out:
# CANCELLED  DIVERTED
# 1.0        0.0         16312
# 0.0        1.0          1166
# Name: count, dtype: int64

# %%
df_clean = df[
    (df["CANCELLED"] == 0) &
    (df["DIVERTED"] == 0)
].copy()

df_clean.shape
# Out:
# (522269, 20)

# %%
df_clean["ARR_DEL15"].value_counts()
# Out:
# ARR_DEL15
# 0.0    424139
# 1.0     98130
# Name: count, dtype: int64

# %%
df_clean["ARR_DEL15"].value_counts(normalize=True) * 100
# Out:
# ARR_DEL15
# 0.0    81.210832
# 1.0    18.789168
# Name: proportion, dtype: float64

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean.nunique().sort_values()
# Out:
# YEAR                    1
# MONTH                   1
# DIVERTED                1
# CANCELLED               1
# ARR_DEL15               2
# DAY_OF_WEEK             7
# OP_UNIQUE_CARRIER      14
# DEP_TIME_BLK           19
# DAY_OF_MONTH           31
# FL_DATE                31
# ORIGIN_STATE_ABR       52
# DEST_STATE_ABR         52
# DEST_CITY_NAME        323
# ORIGIN_CITY_NAME      323
# CRS_ELAPSED_TIME      466
# ARR_DELAY            1153
# CRS_DEP_TIME         1209
# CRS_ARR_TIME         1310
# DISTANCE             1487
# OP_CARRIER_FL_NUM    6388
# dtype: int64

# %%
df_clean.describe()
# Out:
#            YEAR     MONTH   DAY_OF_MONTH    DAY_OF_WEEK  OP_CARRIER_FL_NUM  \
# count  522269.0  522269.0  522269.000000  522269.000000      522269.000000
# mean     2025.0       1.0      15.901246       4.021271        2482.055918
# std         0.0       0.0       9.060014       1.926226        1665.910307
# min      2025.0       1.0       1.000000       1.000000           1.000000
# 25%      2025.0       1.0       8.000000       2.000000        1106.000000
# 50%      2025.0       1.0      16.000000       4.000000        2202.000000
# 75%      2025.0       1.0      24.000000       6.000000        3686.000000
# max      2025.0       1.0      31.000000       7.000000        8819.000000
#
#         CRS_DEP_TIME   CRS_ARR_TIME      ARR_DELAY      ARR_DEL15  CANCELLED  \
# count  522269.000000  522269.000000  522269.000000  522269.000000   522269.0
# mean     1315.261628    1502.718465       3.756614       0.187892        0.0
# ...

# %%
df_clean[
    [
        "CRS_DEP_TIME",
        "CRS_ARR_TIME",
        "CRS_ELAPSED_TIME",
        "DISTANCE",
        "ARR_DELAY"
    ]
].describe()
# Out:
#         CRS_DEP_TIME   CRS_ARR_TIME  CRS_ELAPSED_TIME       DISTANCE  \
# count  522269.000000  522269.000000     522269.000000  522269.000000
# mean     1315.261628    1502.718465        151.882727     847.164503
# std       479.664906     501.501217         74.141967     601.919212
# min         5.000000       1.000000         25.000000      31.000000
# 25%       905.000000    1118.000000         96.000000     403.000000
# 50%      1310.000000    1524.000000        136.000000     712.000000
# 75%      1724.000000    1922.000000        184.000000    1085.000000
# max      2359.000000    2359.000000        693.000000    5095.000000
#
#            ARR_DELAY
# count  522269.000000
# mean        3.756614
# std        56.850884
# min       -87.000000
# 25%       -18.000000
# 50%        -8.000000
# 75%         7.000000
# max      3282.000000

# %%
df_clean.columns.tolist()
# Out:
# ['YEAR',
#  'MONTH',
#  'DAY_OF_MONTH',
#  'DAY_OF_WEEK',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME_BLK',
#  'CRS_ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DEL15',
#  'CANCELLED',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'DISTANCE']

# %%
df_clean.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2025      1             1            3  1/1/2025 12:00:00 AM
# 1  2025      1             1            3  1/1/2025 12:00:00 AM
# 2  2025      1             1            3  1/1/2025 12:00:00 AM
# 3  2025      1             1            3  1/1/2025 12:00:00 AM
# 4  2025      1             1            3  1/1/2025 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# 0                AA                  1      New York, NY               NY
# 1                AA                 10   Los Angeles, CA               CA
# 2                AA               1002       Madison, WI               WI
# 3                AA               1004  Philadelphia, PA               PA
# 4                AA               1005       Chicago, IL               IL
#
#     DEST_CITY_NAME DEST_STATE_ABR  CRS_DEP_TIME DEP_TIME_BLK  CRS_ARR_TIME  \
# ...

# %%
target = "ARR_DEL15"

# %%
drop_columns = [
    "ARR_DEL15",
    "ARR_DELAY",
    "CANCELLED",
    "DIVERTED",
    "YEAR",
    "MONTH"
]

# %%
X = df_clean.drop(columns=drop_columns)

# %%
y = df_clean[target]

# %%
X.shape , y.shape
# Out:
# ((522269, 14), (522269,))

# %%
df_clean["FL_DATE"].min(), df_clean["FL_DATE"].max()
# Out:
# ('1/1/2025 12:00:00 AM', '1/9/2025 12:00:00 AM')

# %%
df_clean["FL_DATE"].value_counts().sort_index()
# Out:
# FL_DATE
# 1/1/2025 12:00:00 AM     16771
# 1/10/2025 12:00:00 AM    14983
# 1/11/2025 12:00:00 AM    14264
# 1/12/2025 12:00:00 AM    18261
# 1/13/2025 12:00:00 AM    17762
# 1/14/2025 12:00:00 AM    15738
# 1/15/2025 12:00:00 AM    16027
# 1/16/2025 12:00:00 AM    18469
# 1/17/2025 12:00:00 AM    18380
# 1/18/2025 12:00:00 AM    14661
# 1/19/2025 12:00:00 AM    15993
# 1/2/2025 12:00:00 AM     19431
# 1/20/2025 12:00:00 AM    18135
# 1/21/2025 12:00:00 AM    14384
# 1/22/2025 12:00:00 AM    14876
# 1/23/2025 12:00:00 AM    17713
# 1/24/2025 12:00:00 AM    18029
# 1/25/2025 12:00:00 AM    14983
# 1/26/2025 12:00:00 AM    18630
# 1/27/2025 12:00:00 AM    17971
# 1/28/2025 12:00:00 AM    15891
# 1/29/2025 12:00:00 AM    15968
# 1/3/2025 12:00:00 AM     19228
# 1/30/2025 12:00:00 AM    17309
# 1/31/2025 12:00:00 AM    17735
# 1/4/2025 12:00:00 AM     18257
# 1/5/2025 12:00:00 AM     18151
# 1/6/2025 12:00:00 AM     16816
# 1/7/2025 12:00:00 AM     15445
# 1/8/2025 12:00:00 AM     16071
# ...

# %%
df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])

df_clean["FL_DATE"].min(), df_clean["FL_DATE"].max()
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_7888\3417552328.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])
# (Timestamp('2025-01-01 00:00:00'), Timestamp('2025-01-31 00:00:00'))

# %%
df_clean["FL_DATE"].value_counts().sort_index()
# Out:
# FL_DATE
# 2025-01-01    16771
# 2025-01-02    19431
# 2025-01-03    19228
# 2025-01-04    18257
# 2025-01-05    18151
# 2025-01-06    16816
# 2025-01-07    15445
# 2025-01-08    16071
# 2025-01-09    15937
# 2025-01-10    14983
# 2025-01-11    14264
# 2025-01-12    18261
# 2025-01-13    17762
# 2025-01-14    15738
# 2025-01-15    16027
# 2025-01-16    18469
# 2025-01-17    18380
# 2025-01-18    14661
# 2025-01-19    15993
# 2025-01-20    18135
# 2025-01-21    14384
# 2025-01-22    14876
# 2025-01-23    17713
# 2025-01-24    18029
# 2025-01-25    14983
# 2025-01-26    18630
# 2025-01-27    17971
# 2025-01-28    15891
# 2025-01-29    15968
# 2025-01-30    17309
# 2025-01-31    17735
# Name: count, dtype: int64

# %%
df_clean["FL_DATE"].min(), df_clean["FL_DATE"].max()
# Out:
# (Timestamp('2025-01-01 00:00:00'), Timestamp('2025-01-31 00:00:00'))

# %%
df_clean.groupby("FL_DATE").size()
# Out:
# FL_DATE
# 2025-01-01    16771
# 2025-01-02    19431
# 2025-01-03    19228
# 2025-01-04    18257
# 2025-01-05    18151
# 2025-01-06    16816
# 2025-01-07    15445
# 2025-01-08    16071
# 2025-01-09    15937
# 2025-01-10    14983
# 2025-01-11    14264
# 2025-01-12    18261
# 2025-01-13    17762
# 2025-01-14    15738
# 2025-01-15    16027
# 2025-01-16    18469
# 2025-01-17    18380
# 2025-01-18    14661
# 2025-01-19    15993
# 2025-01-20    18135
# 2025-01-21    14384
# 2025-01-22    14876
# 2025-01-23    17713
# 2025-01-24    18029
# 2025-01-25    14983
# 2025-01-26    18630
# 2025-01-27    17971
# 2025-01-28    15891
# 2025-01-29    15968
# 2025-01-30    17309
# 2025-01-31    17735
# dtype: int64

# %%
train_df = df_clean[df_clean["FL_DATE"] <= "2025-01-21"].copy()

val_df = df_clean[
    (df_clean["FL_DATE"] >= "2025-01-22") &
    (df_clean["FL_DATE"] <= "2025-01-26")
].copy()

test_df = df_clean[df_clean["FL_DATE"] >= "2025-01-27"].copy()

train_df.shape, val_df.shape, test_df.shape
# Out:
# ((353164, 20), (84231, 20), (84874, 20))

# %%
print("TRAIN")
print(train_df["ARR_DEL15"].value_counts(normalize=True) * 100)

print("\nVALIDATION")
print(val_df["ARR_DEL15"].value_counts(normalize=True) * 100)

print("\nTEST")
print(test_df["ARR_DEL15"].value_counts(normalize=True) * 100)
# Out:
# TRAIN
# ARR_DEL15
# 0.0    78.672232
# 1.0    21.327768
# Name: proportion, dtype: float64
#
# VALIDATION
# ARR_DEL15
# 0.0    84.084245
# 1.0    15.915755
# Name: proportion, dtype: float64
#
# TEST
# ARR_DEL15
# 0.0    88.922403
# 1.0    11.077597
# Name: proportion, dtype: float64

# %%
def add_date_features(data):
    data = data.copy()

    data["DAY_OF_MONTH"] = data["FL_DATE"].dt.day
    data["DAY_OF_WEEK"] = data["FL_DATE"].dt.dayofweek
    data["WEEK_OF_MONTH"] = ((data["FL_DATE"].dt.day - 1) // 7) + 1

    return data

# %%
train_df = add_date_features(train_df)
val_df = add_date_features(val_df)
test_df = add_date_features(test_df)

# %%
train_df.shape
# Out:
# (353164, 21)

# %%
train_df.head(
    
)
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK    FL_DATE OP_UNIQUE_CARRIER  \
# 0  2025      1             1            2 2025-01-01                AA
# 1  2025      1             1            2 2025-01-01                AA
# 2  2025      1             1            2 2025-01-01                AA
# 3  2025      1             1            2 2025-01-01                AA
# 4  2025      1             1            2 2025-01-01                AA
#
#    OP_CARRIER_FL_NUM  ORIGIN_CITY_NAME ORIGIN_STATE_ABR   DEST_CITY_NAME  ...  \
# 0                  1      New York, NY               NY  Los Angeles, CA  ...
# 1                 10   Los Angeles, CA               CA     New York, NY  ...
# 2               1002       Madison, WI               WI    Charlotte, NC  ...
# 3               1004  Philadelphia, PA               PA    Las Vegas, NV  ...
# 4               1005       Chicago, IL               IL      Phoenix, AZ  ...
#
# ...

# %%
def add_time_features(data):
    data = data.copy()

    # Convert HHMM format into hour and minute
    data["DEP_HOUR"] = data["CRS_DEP_TIME"] // 100
    data["DEP_MINUTE"] = data["CRS_DEP_TIME"] % 100

    # Same for scheduled arrival
    data["ARR_HOUR"] = data["CRS_ARR_TIME"] // 100
    data["ARR_MINUTE"] = data["CRS_ARR_TIME"] % 100

    return data

# %%
train_df = add_time_features(train_df)
val_df = add_time_features(val_df)
test_df = add_time_features(test_df)

# %%
train_df[
    ["CRS_DEP_TIME", "DEP_HOUR", "DEP_MINUTE",
     "CRS_ARR_TIME", "ARR_HOUR", "ARR_MINUTE"]
].head()
# Out:
#    CRS_DEP_TIME  DEP_HOUR  DEP_MINUTE  CRS_ARR_TIME  ARR_HOUR  ARR_MINUTE
# 0           659         6          59          1020        10          20
# 1          2200        22           0           630         6          30
# 2           644         6          44          1005        10           5
# 3          1855        18          55          2134        21          34
# 4           830         8          30          1131        11          31

# %%
def add_time_features(data):
    data = data.copy()

    data["DEP_HOUR"] = data["CRS_DEP_TIME"] // 100
    data["DEP_MINUTE"] = data["CRS_DEP_TIME"] % 100

    data["ARR_HOUR"] = data["CRS_ARR_TIME"] // 100
    data["ARR_MINUTE"] = data["CRS_ARR_TIME"] % 100

    return data

# %%
def add_time_features(data):
    data = data.copy()

    data["DEP_HOUR"] = data["CRS_DEP_TIME"] // 100
    data["DEP_MINUTE"] = data["CRS_DEP_TIME"] % 100

    data["ARR_HOUR"] = data["CRS_ARR_TIME"] // 100
    data["ARR_MINUTE"] = data["CRS_ARR_TIME"] % 100

    return data

# %%
train_df[
    ["CRS_DEP_TIME", "DEP_HOUR", "DEP_MINUTE",
     "CRS_ARR_TIME", "ARR_HOUR", "ARR_MINUTE"]
].head()
# Out:
#    CRS_DEP_TIME  DEP_HOUR  DEP_MINUTE  CRS_ARR_TIME  ARR_HOUR  ARR_MINUTE
# 0           659         6          59          1020        10          20
# 1          2200        22           0           630         6          30
# 2           644         6          44          1005        10           5
# 3          1855        18          55          2134        21          34
# 4           830         8          30          1131        11          31

# %%
feature_columns = [
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",
    "WEEK_OF_MONTH",
    "OP_UNIQUE_CARRIER",
    "ORIGIN_CITY_NAME",
    "ORIGIN_STATE_ABR",
    "DEST_CITY_NAME",
    "DEST_STATE_ABR",
    "DEP_HOUR",
    "DEP_MINUTE",
    "ARR_HOUR",
    "ARR_MINUTE",
    "CRS_ELAPSED_TIME",
    "DISTANCE"
]

target = "ARR_DEL15"

X_train = train_df[feature_columns]
y_train = train_df[target]

X_val = val_df[feature_columns]
y_val = val_df[target]

X_test = test_df[feature_columns]
y_test = test_df[target]

X_train.shape, X_val.shape, X_test.shape
# Out:
# ((353164, 14), (84231, 14), (84874, 14))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import  StandardScaler

# %%
numeric_features = [
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",
    "WEEK_OF_MONTH",
    "DEP_HOUR",
    "DEP_MINUTE",
    "ARR_HOUR",
    "ARR_MINUTE",
    "CRS_ELAPSED_TIME",
    "DISTANCE"
]

categorical_features = [
    "OP_UNIQUE_CARRIER",
    "ORIGIN_CITY_NAME",
    "ORIGIN_STATE_ABR",
    "DEST_CITY_NAME",
    "DEST_STATE_ABR"
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            "passthrough",
            numeric_features
        ),
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore"
            ),
            categorical_features
        )
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            StandardScaler(),
            numeric_features
        ),
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ]
)

# %% [markdown]
# Creating the dummy classifier , afterwards will compare with logistic regression

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
dummy_model = DummyClassifier(strategy="most_frequent")

dummy_model.fit(X_train, y_train)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
dummy_predictions = dummy_model.predict(X_val)

# %%
print("Accuracy:", accuracy_score(y_val, dummy_predictions))
print("Precision:", precision_score(y_val, dummy_predictions, zero_division=0))
print("Recall:", recall_score(y_val, dummy_predictions, zero_division=0))
print("F1 Score:", f1_score(y_val, dummy_predictions, zero_division=0))
# Out:
# Accuracy: 0.8408424451805155
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LogisticRegression(
            max_iter=1000,
            class_weight="balanced"
        ))
    ]
)

# %%
logistic_model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['DAY_OF_MONTH',
#                                                    'DAY_OF_WEEK',
#                                                    'WEEK_OF_MONTH', 'DEP_HOUR',
#                                                    'DEP_MINUTE', 'ARR_HOUR',
#                                                    'ARR_MINUTE',
#                                                    'CRS_ELAPSED_TIME',
#                                                    'DISTANCE']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['OP_UNIQUE_CARRIER',
#                                                    'ORIGIN_CITY_NAME',
#                                                    'ORIGIN_STATE_ABR',
# ...

# %%
val_predictions = logistic_model.predict(X_val)

# %%
val_probabilities = logistic_model.predict_proba(X_val)[:, 1]

# %%
val_probabilities
# Out:
# array([0.19060893, 0.22372408, 0.13361952, ..., 0.53829671, 0.35240092,
#        0.39757019], shape=(84231,))

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

print("Accuracy :", accuracy_score(y_val, val_predictions))
print("Precision:", precision_score(y_val, val_predictions))
print("Recall   :", recall_score(y_val, val_predictions))
print("F1 Score :", f1_score(y_val, val_predictions))
print("ROC-AUC  :", roc_auc_score(y_val, val_probabilities))
# Out:
# Accuracy : 0.7820873550118127
# Precision: 0.19522108634068236
# Recall   : 0.11823064299567358
# F1 Score : 0.14727061556329848
# ROC-AUC  : 0.5597340775863671

# %% [markdown]
# Now testing with random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", RandomForestClassifier(
            n_estimators=100,
            max_depth=12,
            random_state=42,
            n_jobs=-1,
            class_weight="balanced"
        ))
    ]
)

# %%
random_forest_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['DAY_OF_MONTH',
#                                                    'DAY_OF_WEEK',
#                                                    'WEEK_OF_MONTH', 'DEP_HOUR',
#                                                    'DEP_MINUTE', 'ARR_HOUR',
#                                                    'ARR_MINUTE',
#                                                    'CRS_ELAPSED_TIME',
#                                                    'DISTANCE']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['OP_UNIQUE_CARRIER',
#                                                    'ORIGIN_CITY_NAME',
#                                                    'ORIGIN_STATE_ABR',
# ...

# %%
rf_predictions = random_forest_model.predict(X_val)

rf_probabilities = random_forest_model.predict_proba(X_val)[:, 1]

# %%
print("Accuracy :", accuracy_score(y_val, rf_predictions))
print("Precision:", precision_score(y_val, rf_predictions))
print("Recall   :", recall_score(y_val, rf_predictions))
print("F1 Score :", f1_score(y_val, rf_predictions))
print("ROC-AUC  :", roc_auc_score(y_val, rf_probabilities))
# Out:
# Accuracy : 0.7062245491564864
# Precision: 0.2109020447707919
# Recall   : 0.3085185737729375
# F1 Score : 0.2505376018414756
# ROC-AUC  : 0.6009718483260231

# %% [markdown]
# Feature Engineering

# %%
# Sort chronologically
df_clean = df_clean.sort_values(
    ["FL_DATE", "CRS_DEP_TIME", "OP_CARRIER_FL_NUM"]
).copy()

# %%
# Create daily airline statistics
carrier_daily = (
    df_clean
    .groupby(["FL_DATE", "OP_UNIQUE_CARRIER"])["ARR_DEL15"]
    .agg(["sum", "count"])
    .reset_index()
)

carrier_daily.head()
# Out:
#      FL_DATE OP_UNIQUE_CARRIER    sum  count
# 0 2025-01-01                AA  299.0   2403
# 1 2025-01-01                AS   65.0    623
# 2 2025-01-01                B6  201.0    697
# 3 2025-01-01                DL  250.0   2101
# 4 2025-01-01                F9  151.0    563

# %%
carrier_daily = carrier_daily.sort_values(
    ["OP_UNIQUE_CARRIER", "FL_DATE"]
).copy()

carrier_daily["previous_delays"] = (
    carrier_daily
    .groupby("OP_UNIQUE_CARRIER")["sum"]
    .cumsum()
    - carrier_daily["sum"]
)

carrier_daily["previous_flights"] = (
    carrier_daily
    .groupby("OP_UNIQUE_CARRIER")["count"]
    .cumsum()
    - carrier_daily["count"]
)

carrier_daily["carrier_historical_delay_rate"] = (
    carrier_daily["previous_delays"]
    / carrier_daily["previous_flights"]
)

# %%
df_clean = df_clean.merge(
    carrier_daily[
        [
            "FL_DATE",
            "OP_UNIQUE_CARRIER",
            "carrier_historical_delay_rate"
        ]
    ],
    on=["FL_DATE", "OP_UNIQUE_CARRIER"],
    how="left"
)

# %%
df_clean[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "ARR_DEL15",
        "carrier_historical_delay_rate"
    ]
].head(20)
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  ARR_DEL15  carrier_historical_delay_rate
# 0  2025-01-01                DL        0.0                            NaN
# 1  2025-01-01                AA        0.0                            NaN
# 2  2025-01-01                AS        0.0                            NaN
# 3  2025-01-01                AA        0.0                            NaN
# 4  2025-01-01                AA        0.0                            NaN
# 5  2025-01-01                UA        0.0                            NaN
# 6  2025-01-01                F9        0.0                            NaN
# 7  2025-01-01                UA        0.0                            NaN
# 8  2025-01-01                AA        0.0                            NaN
# 9  2025-01-01                AS        0.0                            NaN
# 10 2025-01-01                UA        1.0                            NaN
# 11 2025-01-01                AA        0.0                            NaN
# ...

# %%
overall_delay_rate = y_train.mean()

overall_delay_rate
# Out:
# np.float64(0.21327768402215402)

# %%
df_clean["carrier_historical_delay_rate"] = (
    df_clean["carrier_historical_delay_rate"]
    .fillna(overall_delay_rate)
)

# %%
df_clean[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "ARR_DEL15",
        "carrier_historical_delay_rate"
    ]
].head(20)
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  ARR_DEL15  carrier_historical_delay_rate
# 0  2025-01-01                DL        0.0                       0.213278
# 1  2025-01-01                AA        0.0                       0.213278
# 2  2025-01-01                AS        0.0                       0.213278
# 3  2025-01-01                AA        0.0                       0.213278
# 4  2025-01-01                AA        0.0                       0.213278
# 5  2025-01-01                UA        0.0                       0.213278
# 6  2025-01-01                F9        0.0                       0.213278
# 7  2025-01-01                UA        0.0                       0.213278
# 8  2025-01-01                AA        0.0                       0.213278
# 9  2025-01-01                AS        0.0                       0.213278
# 10 2025-01-01                UA        1.0                       0.213278
# 11 2025-01-01                AA        0.0                       0.213278
# ...

# %%
df_clean = df[
    (df["CANCELLED"] == 0) &
    (df["DIVERTED"] == 0)
].copy()

df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])

df_clean = df_clean.sort_values(
    ["FL_DATE", "CRS_DEP_TIME", "OP_CARRIER_FL_NUM"]
).reset_index(drop=True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_7888\3665410243.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])

# %%
train_df = df_clean[df_clean["FL_DATE"] <= "2025-01-21"].copy()

val_df = df_clean[
    (df_clean["FL_DATE"] >= "2025-01-22") &
    (df_clean["FL_DATE"] <= "2025-01-26")
].copy()

test_df = df_clean[df_clean["FL_DATE"] >= "2025-01-27"].copy()

# %%
carrier_stats = (
    train_df
    .groupby("OP_UNIQUE_CARRIER")["ARR_DEL15"]
    .agg(["sum", "count"])
)

carrier_stats["carrier_historical_delay_rate"] = (
    carrier_stats["sum"] / carrier_stats["count"]
)

carrier_stats
# Out:
#                        sum  count  carrier_historical_delay_rate
# OP_UNIQUE_CARRIER
# AA                 10228.0  48416                       0.211252
# AS                  2420.0  12194                       0.198458
# B6                  3419.0  12168                       0.280983
# DL                 10518.0  48791                       0.215573
# F9                  3106.0  10383                       0.299143
# G4                  1748.0   6402                       0.273040
# HA                   499.0   4512                       0.110594
# MQ                  2910.0  14060                       0.206970
# NK                  2354.0  11657                       0.201939
# OH                  3710.0  13152                       0.282086
# OO                 10105.0  42563                       0.237413
# UA                  8257.0  41070                       0.201047
# WN                 12586.0  70125                       0.179480
# ...

# %%
val_df = val_df.merge(
    carrier_stats["carrier_historical_delay_rate"],
    on="OP_UNIQUE_CARRIER",
    how="left"
)

# %%
val_df[
    ["FL_DATE", "OP_UNIQUE_CARRIER", "ARR_DEL15",
     "carrier_historical_delay_rate"]
].head(20)
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  ARR_DEL15  carrier_historical_delay_rate
# 0  2025-01-22                UA        0.0                       0.201047
# 1  2025-01-22                AA        0.0                       0.211252
# 2  2025-01-22                AS        1.0                       0.198458
# 3  2025-01-22                DL        0.0                       0.215573
# 4  2025-01-22                AA        0.0                       0.211252
# 5  2025-01-22                AA        0.0                       0.211252
# 6  2025-01-22                F9        0.0                       0.299143
# 7  2025-01-22                AA        0.0                       0.211252
# 8  2025-01-22                DL        0.0                       0.215573
# 9  2025-01-22                AA        0.0                       0.211252
# 10 2025-01-22                UA        0.0                       0.201047
# 11 2025-01-22                DL        0.0                       0.215573
# ...

# %%
history_df = pd.concat([train_df, val_df], ignore_index=True)

carrier_test_stats = (
    history_df
    .groupby("OP_UNIQUE_CARRIER")["ARR_DEL15"]
    .agg(["sum", "count"])
)

carrier_test_stats["carrier_historical_delay_rate"] = (
    carrier_test_stats["sum"] / carrier_test_stats["count"]
)

# %%
test_df = test_df.merge(
    carrier_test_stats["carrier_historical_delay_rate"],
    on="OP_UNIQUE_CARRIER",
    how="left"
)

# %%
test_df[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "ARR_DEL15",
        "carrier_historical_delay_rate"
    ]
].head(20)
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  ARR_DEL15  carrier_historical_delay_rate
# 0  2025-01-27                UA        0.0                       0.191425
# 1  2025-01-27                AA        0.0                       0.203309
# 2  2025-01-27                AA        0.0                       0.203309
# 3  2025-01-27                AS        0.0                       0.185020
# 4  2025-01-27                DL        0.0                       0.212971
# 5  2025-01-27                DL        0.0                       0.212971
# 6  2025-01-27                AA        0.0                       0.203309
# 7  2025-01-27                AA        0.0                       0.203309
# 8  2025-01-27                AA        0.0                       0.203309
# 9  2025-01-27                AS        0.0                       0.185020
# 10 2025-01-27                F9        0.0                       0.281074
# 11 2025-01-27                UA        0.0                       0.191425
# ...

# %%
train_daily = (
    train_df
    .groupby(["FL_DATE", "OP_UNIQUE_CARRIER"])["ARR_DEL15"]
    .agg(["sum", "count"])
    .reset_index()
)

train_daily = train_daily.sort_values(
    ["OP_UNIQUE_CARRIER", "FL_DATE"]
).copy()

# %%
train_daily["previous_delays"] = (
    train_daily
    .groupby("OP_UNIQUE_CARRIER")["sum"]
    .cumsum()
    - train_daily["sum"]
)

train_daily["previous_flights"] = (
    train_daily
    .groupby("OP_UNIQUE_CARRIER")["count"]
    .cumsum()
    - train_daily["count"]
)

train_daily["carrier_historical_delay_rate"] = (
    train_daily["previous_delays"]
    / train_daily["previous_flights"]
)

# %%
train_df = train_df.merge(
    train_daily[
        [
            "FL_DATE",
            "OP_UNIQUE_CARRIER",
            "carrier_historical_delay_rate"
        ]
    ],
    on=["FL_DATE", "OP_UNIQUE_CARRIER"],
    how="left"
)

# %%
train_df[
    [
        "FL_DATE",
        "OP_UNIQUE_CARRIER",
        "ARR_DEL15",
        "carrier_historical_delay_rate"
    ]
].head(20)
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  ARR_DEL15  carrier_historical_delay_rate
# 0  2025-01-01                DL        0.0                            NaN
# 1  2025-01-01                AA        0.0                            NaN
# 2  2025-01-01                AS        0.0                            NaN
# 3  2025-01-01                AA        0.0                            NaN
# 4  2025-01-01                AA        0.0                            NaN
# 5  2025-01-01                UA        0.0                            NaN
# 6  2025-01-01                F9        0.0                            NaN
# 7  2025-01-01                UA        0.0                            NaN
# 8  2025-01-01                AA        0.0                            NaN
# 9  2025-01-01                AS        0.0                            NaN
# 10 2025-01-01                UA        1.0                            NaN
# 11 2025-01-01                AA        0.0                            NaN
# ...

# %%
train_df = train_df.dropna(
    subset=["carrier_historical_delay_rate"]
).copy()

# %%
train_df["carrier_historical_delay_rate"].isna().sum()
# Out:
# np.int64(0)

# %%
# ============================================================
# LEAKAGE-SAFE HISTORICAL FEATURE ENGINEERING
# ============================================================

# Started again from the original clean dataset
df_clean = df[
    (df["CANCELLED"] == 0) &
    (df["DIVERTED"] == 0)
].copy()

# Convert date
df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])

# Sort chronologically
df_clean = df_clean.sort_values(
    ["FL_DATE", "CRS_DEP_TIME", "OP_CARRIER_FL_NUM"]
).reset_index(drop=True)


# ------------------------------------------------------------
# 1. Basic features
# ------------------------------------------------------------

df_clean["DAY_OF_MONTH"] = df_clean["FL_DATE"].dt.day
df_clean["DAY_OF_WEEK"] = df_clean["FL_DATE"].dt.dayofweek
df_clean["WEEK_OF_MONTH"] = (
    (df_clean["FL_DATE"].dt.day - 1) // 7
) + 1

df_clean["DEP_HOUR"] = df_clean["CRS_DEP_TIME"] // 100
df_clean["DEP_MINUTE"] = df_clean["CRS_DEP_TIME"] % 100

df_clean["ARR_HOUR"] = df_clean["CRS_ARR_TIME"] // 100
df_clean["ARR_MINUTE"] = df_clean["CRS_ARR_TIME"] % 100


# ------------------------------------------------------------
# 2. Create route
# ------------------------------------------------------------

df_clean["ROUTE"] = (
    df_clean["ORIGIN_CITY_NAME"]
    + " -> "
    + df_clean["DEST_CITY_NAME"]
)


# ------------------------------------------------------------
# 3. Function to create leakage-safe historical delay rate
# ------------------------------------------------------------

def add_historical_delay_rate(data, group_columns, feature_name):
    
    # Daily statistics
    daily = (
        data
        .groupby(group_columns + ["FL_DATE"])["ARR_DEL15"]
        .agg(["sum", "count"])
        .reset_index()
    )

    # Sort by group + date
    daily = daily.sort_values(
        group_columns + ["FL_DATE"]
    ).copy()

    # Cumulative values
    daily["cumulative_delays"] = (
        daily
        .groupby(group_columns)["sum"]
        .cumsum()
    )

    daily["cumulative_flights"] = (
        daily
        .groupby(group_columns)["count"]
        .cumsum()
    )

    # Remove CURRENT day's information
    daily["previous_delays"] = (
        daily["cumulative_delays"]
        - daily["sum"]
    )

    daily["previous_flights"] = (
        daily["cumulative_flights"]
        - daily["count"]
    )

    # Historical rate using ONLY previous days
    daily[feature_name] = (
        daily["previous_delays"]
        / daily["previous_flights"]
    )

    # Keep only columns needed for merging
    merge_columns = group_columns + [
        "FL_DATE",
        feature_name
    ]

    daily = daily[merge_columns]

    # Merge back into original data
    data = data.merge(
        daily,
        on=group_columns + ["FL_DATE"],
        how="left"
    )

    return data


# ------------------------------------------------------------
# 4. Airline historical delay rate
# ------------------------------------------------------------

df_clean = add_historical_delay_rate(
    df_clean,
    ["OP_UNIQUE_CARRIER"],
    "carrier_historical_delay_rate"
)


# ------------------------------------------------------------
# 5. Origin historical delay rate
# ------------------------------------------------------------

df_clean = add_historical_delay_rate(
    df_clean,
    ["ORIGIN_CITY_NAME"],
    "origin_historical_delay_rate"
)


# ------------------------------------------------------------
# 6. Destination historical delay rate
# ------------------------------------------------------------

df_clean = add_historical_delay_rate(
    df_clean,
    ["DEST_CITY_NAME"],
    "destination_historical_delay_rate"
)


# ------------------------------------------------------------
# 7. Route historical delay rate
# ------------------------------------------------------------

df_clean = add_historical_delay_rate(
    df_clean,
    ["ROUTE"],
    "route_historical_delay_rate"
)


# ------------------------------------------------------------
# 8. Departure-hour historical delay rate
# ------------------------------------------------------------

df_clean = add_historical_delay_rate(
    df_clean,
    ["DEP_HOUR"],
    "departure_hour_historical_delay_rate"
)


# ------------------------------------------------------------
# 9. Create chronological train / validation / test
# ------------------------------------------------------------

train_df = df_clean[
    df_clean["FL_DATE"] <= "2025-01-21"
].copy()

val_df = df_clean[
    (df_clean["FL_DATE"] >= "2025-01-22") &
    (df_clean["FL_DATE"] <= "2025-01-26")
].copy()

test_df = df_clean[
    df_clean["FL_DATE"] >= "2025-01-27"
].copy()


# ------------------------------------------------------------
# 10. Fill missing historical values
# ------------------------------------------------------------
# Missing values occur mainly when there is no previous history.
# Use ONLY the training-set overall delay rate as fallback.

overall_delay_rate = train_df["ARR_DEL15"].mean()

historical_features = [
    "carrier_historical_delay_rate",
    "origin_historical_delay_rate",
    "destination_historical_delay_rate",
    "route_historical_delay_rate",
    "departure_hour_historical_delay_rate"
]

for feature in historical_features:
    train_df[feature] = train_df[feature].fillna(
        overall_delay_rate
    )

    val_df[feature] = val_df[feature].fillna(
        overall_delay_rate
    )

    test_df[feature] = test_df[feature].fillna(
        overall_delay_rate
    )


# ------------------------------------------------------------
# 11. Define final features
# ------------------------------------------------------------

feature_columns = [
    # Date
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",
    "WEEK_OF_MONTH",

    # Flight information
    "OP_UNIQUE_CARRIER",
    "ORIGIN_CITY_NAME",
    "ORIGIN_STATE_ABR",
    "DEST_CITY_NAME",
    "DEST_STATE_ABR",

    # Time
    "DEP_HOUR",
    "DEP_MINUTE",
    "ARR_HOUR",
    "ARR_MINUTE",

    # Numeric
    "CRS_ELAPSED_TIME",
    "DISTANCE",

    # Historical features
    "carrier_historical_delay_rate",
    "origin_historical_delay_rate",
    "destination_historical_delay_rate",
    "route_historical_delay_rate",
    "departure_hour_historical_delay_rate"
]

target = "ARR_DEL15"


# ------------------------------------------------------------
# 12. Create X and y
# ------------------------------------------------------------

X_train = train_df[feature_columns]
y_train = train_df[target]

X_val = val_df[feature_columns]
y_val = val_df[target]

X_test = test_df[feature_columns]
y_test = test_df[target]


# ------------------------------------------------------------
# 13. Verify everything
# ------------------------------------------------------------

print("Train shape:", X_train.shape)
print("Validation shape:", X_val.shape)
print("Test shape:", X_test.shape)

print("\nHistorical feature missing values:")
print(
    X_train[historical_features]
    .isna()
    .sum()
)

print("\nHistorical feature statistics:")
print(
    X_train[historical_features]
    .describe()
)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_7888\2103850661.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean["FL_DATE"] = pd.to_datetime(df_clean["FL_DATE"])
# Train shape: (353164, 19)
# Validation shape: (84231, 19)
# Test shape: (84874, 19)
#
# Historical feature missing values:
# carrier_historical_delay_rate           0
# origin_historical_delay_rate            0
# destination_historical_delay_rate       0
# route_historical_delay_rate             0
# departure_hour_historical_delay_rate    0
# dtype: int64
#
# Historical feature statistics:
#        carrier_historical_delay_rate  origin_historical_delay_rate  \
# count                  353164.000000                 353164.000000
# mean                        0.224712                      0.225498
# std                         0.049085                      0.073117
# ...

# %%
print("Train shape:", X_train.shape)
print("Validation shape:", X_val.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (353164, 19)
# Validation shape: (84231, 19)
# Test shape: (84874, 19)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression


numeric_features = [
    "DAY_OF_MONTH",
    "DAY_OF_WEEK",
    "WEEK_OF_MONTH",
    "DEP_HOUR",
    "DEP_MINUTE",
    "ARR_HOUR",
    "ARR_MINUTE",
    "CRS_ELAPSED_TIME",
    "DISTANCE",
    "carrier_historical_delay_rate",
    "origin_historical_delay_rate",
    "destination_historical_delay_rate",
    "route_historical_delay_rate",
    "departure_hour_historical_delay_rate"
]

categorical_features = [
    "OP_UNIQUE_CARRIER",
    "ORIGIN_CITY_NAME",
    "ORIGIN_STATE_ABR",
    "DEST_CITY_NAME",
    "DEST_STATE_ABR"
]


preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)


logistic_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LogisticRegression(
            max_iter=1000,
            class_weight="balanced"
        ))
    ]
)


logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['DAY_OF_MONTH',
#                                                    'DAY_OF_WEEK',
#                                                    'WEEK_OF_MONTH', 'DEP_HOUR',
#                                                    'DEP_MINUTE', 'ARR_HOUR',
#                                                    'ARR_MINUTE',
#                                                    'CRS_ELAPSED_TIME',
#                                                    'DISTANCE',
#                                                    'carrier_historical_delay_rate',
#                                                    'origin_historical_delay_rate',
#                                                    'destination_historical_delay_rate',
#                                                    'route_historical_delay_rate',
# ...

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

lr_predictions = logistic_model.predict(X_val)
lr_probabilities = logistic_model.predict_proba(X_val)[:, 1]

print("Accuracy :", accuracy_score(y_val, lr_predictions))
print("Precision:", precision_score(y_val, lr_predictions))
print("Recall   :", recall_score(y_val, lr_predictions))
print("F1 Score :", f1_score(y_val, lr_predictions))
print("ROC-AUC  :", roc_auc_score(y_val, lr_probabilities))
# Out:
# Accuracy : 0.785815198679821
# Precision: 0.2112869066899215
# Recall   : 0.12651051767865135
# F1 Score : 0.15826062613726496
# ROC-AUC  : 0.5624922337749206

# %% [markdown]
# Testing with xgboost model

# %%
import xgboost as xgb

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

# %%
xgb_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", XGBClassifier(
            n_estimators=200,
            max_depth=6,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            objective="binary:logistic",
            eval_metric="logloss",
            random_state=42,
            n_jobs=-1,
            tree_method="hist"
        ))
    ]
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['DAY_OF_MONTH',
#                                                    'DAY_OF_WEEK',
#                                                    'WEEK_OF_MONTH', 'DEP_HOUR',
#                                                    'DEP_MINUTE', 'ARR_HOUR',
#                                                    'ARR_MINUTE',
#                                                    'CRS_ELAPSED_TIME',
#                                                    'DISTANCE',
#                                                    'carrier_historical_delay_rate',
#                                                    'origin_historical_delay_rate',
#                                                    'destination_historical_delay_rate',
#                                                    'route_historical_delay_rate',
# ...

# %%
xgb_predictions = xgb_model.predict(X_val)
xgb_probabilities = xgb_model.predict_proba(X_val)[:, 1]

print("Accuracy :", accuracy_score(y_val, xgb_predictions))
print("Precision:", precision_score(y_val, xgb_predictions))
print("Recall   :", recall_score(y_val, xgb_predictions))
print("F1 Score :", f1_score(y_val, xgb_predictions))
print("ROC-AUC  :", roc_auc_score(y_val, xgb_probabilities))
# Out:
# Accuracy : 0.8285548076123992
# Precision: 0.2892057026476578
# Recall   : 0.052961360584812774
# F1 Score : 0.08952777252380052
# ROC-AUC  : 0.6145569851159048

# %% [markdown]
# Checking best thresholds

# %%
import numpy as np
import pandas as pd

threshold_results = []

for threshold in np.arange(0.10, 0.56, 0.05):

    predictions = (
        xgb_probabilities >= threshold
    ).astype(int)

    threshold_results.append({
        "Threshold": round(threshold, 2),
        "Accuracy": accuracy_score(y_val, predictions),
        "Precision": precision_score(
            y_val, predictions, zero_division=0
        ),
        "Recall": recall_score(
            y_val, predictions, zero_division=0
        ),
        "F1": f1_score(
            y_val, predictions, zero_division=0
        )
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#    Threshold  Accuracy  Precision    Recall        F1
# 0       0.10  0.261804   0.171071  0.946069  0.289748
# 1       0.15  0.406477   0.186718  0.813293  0.303709
# 2       0.20  0.532156   0.200760  0.650604  0.306837
# 3       0.25  0.626931   0.212998  0.498732  0.298509
# 4       0.30  0.710534   0.231874  0.354021  0.280215
# 5       0.35  0.766262   0.245131  0.225347  0.234823
# 6       0.40  0.798328   0.252111  0.135835  0.176548
# 7       0.45  0.815911   0.261038  0.085559  0.128876
# 8       0.50  0.828555   0.289206  0.052961  0.089528
# 9       0.55  0.835001   0.318047  0.032075  0.058273

# %%
best_threshold_row = threshold_df.loc[
    threshold_df["F1"].idxmax()
]

best_threshold_row
# Out:
# Threshold    0.200000
# Accuracy     0.532156
# Precision    0.200760
# Recall       0.650604
# F1           0.306837
# Name: 2, dtype: float64

# %%
print("Minimum probability:", xgb_probabilities.min())
print("Maximum probability:", xgb_probabilities.max())
print("Mean probability:", xgb_probabilities.mean())

print("\nProbability percentiles:")

print(
    np.percentile(
        xgb_probabilities,
        [25, 50, 75, 90, 95, 99]
    )
)
# Out:
# Minimum probability: 0.024582712
# Maximum probability: 0.81489503
# Mean probability: 0.22697541
#
# Probability percentiles:
# [0.13543326 0.20526727 0.29678166 0.38534525 0.4543351  0.5895982 ]

# %%
from sklearn.metrics import average_precision_score

pr_auc = average_precision_score(
    y_val,
    xgb_probabilities
)

print("PR-AUC:", pr_auc)
# Out:
# PR-AUC: 0.21978218603583205
